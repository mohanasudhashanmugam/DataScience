# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("kidney_disease.csv")

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
from UnivariateFile import UnivariateAnalysis as ua
Quan,Qual=ua.univariate(dataset)
Quan
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']

# %%
dataset[Quan].isna().sum()
# Out:
# id       0
# age      9
# bp      12
# sg      47
# al      46
# su      49
# bgr     44
# bu      19
# sc      17
# sod     87
# pot     88
# hemo    52
# dtype: int64

# %%
#import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
###imp_mean = SimpleImputer(missing_values=np.nan,strategy='constant', fill_value=0)
#imp_mean.fit(dataset[Quan])
#imp_Quan=imp_mean.transform(dataset[Quan])
imp_Quan=imp_mean.fit_transform(dataset[Quan])
imp_Quan
# Out:
# array([[  0.        ,  48.        ,  80.        , ..., 137.52875399,
#           4.62724359,  15.4       ],
#        [  1.        ,   7.        ,  50.        , ..., 137.52875399,
#           4.62724359,  11.3       ],
#        [  2.        ,  62.        ,  80.        , ..., 137.52875399,
#           4.62724359,   9.6       ],
#        ...,
#        [397.        ,  12.        ,  80.        , ..., 137.        ,
#           4.4       ,  15.8       ],
#        [398.        ,  17.        ,  60.        , ..., 135.        ,
#           4.9       ,  14.2       ],
#        [399.        ,  58.        ,  80.        , ..., 141.        ,
#           3.5       ,  15.8       ]])

# %%
post_dataset=pd.DataFrame(imp_Quan, columns=[Quan])
post_dataset
# Out:
#         id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    0.0  0.0  15.4
# 1      1.0   7.0  50.0  1.020  4.0  0.0    0.0  18.0  0.8    0.0  0.0  11.3
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    0.0  0.0   9.6
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    0.0  0.0  11.6
# ..     ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
post_dataset.isna().sum()
# Out:
# id      0
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# dtype: int64
